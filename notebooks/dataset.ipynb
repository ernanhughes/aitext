# %%
import pandas as pd
from datasets import load_dataset

dataset = load_dataset("1-800-SHARED-TASKS/COLING-2025-GENAI-MULTI")

# Load dataset from Hugging Face
dataset = load_dataset("NicolaiSivesind/human-vs-machine", "research_abstracts_labeled")

# Convert to DataFrame
df_train = pd.DataFrame(dataset["train"])
df_test = pd.DataFrame(dataset["test"])

print(df_train.head())

# df = pd.DataFrame(dataset["train"])
# df["label"] = df["label"].map({"human": 0, "AI": 1})  # Convert to numeric labels
# print(df.head())
df_train.head(100).to_csv("first_100_rows.csv", index=False)

print("✅ First 100 rows saved to 'first_100_rows.csv'")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File d:\projects\aitext\venv\Lib\site-packages\huggingface_hub\file_download.py:428, in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries, _tqdm_bar)
#     427 try:
# --> 428     hf_transfer.download(
#     429         url=url,
#     430         filename=temp_file.name,
#     431         max_files=constants.HF_TRANSFER_CONCURRENCY,
#     432         chunk_size=constants.DOWNLOAD_CHUNK_SIZE,
#     433         headers=headers,
#     434         parallel_failures=3,
#     435         max_retries=5,
#     436         **({"callback": progress.update} if supports_callback else {}),
#     437     )
#     438 except Exception as e:
#
# Exception: Error while removing corrupted file: The process cannot access the file because it is being used by another process. (os error 32)
#
# ...
